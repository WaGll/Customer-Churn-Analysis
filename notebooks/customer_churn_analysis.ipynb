# %% [markdown]
# # 客户流失大数据挖掘
#
# ## 一、数据预览与质量评估
#
# ### （一） **数据预览**
# - 使用 `src.data_loader.DataLoader` 加载数据，自动生成结构化质量报告。
# - 查看数据整体信息摘要和基础统计信息。明确整体数据结构。
#
# ### （二） **数据质量评估**
#
# 1. **缺失值检测与处理**：检测缺失值并进行相应处理。
# 2. **重复值检测与处理**：检测重复值行并删除。
# 3. **异常值检测与处理**：
# - 对数值型变量，绘制直方图和箱线图进行可视化分析。
# - 使用 `src.utils.helpers.detect_outliers_iqr` 进行 IQR 异常值检测。
# - 对于分类变量，绘制各类别的频次分布图。
#
# ## 二、数据处理与特征工程
#
# ### （一）数据筛选
# - 深复制原表，删除无关实验变量，筛选出分类变量与数值变量。
#
# ### （二）数值变量离散化
# - **聚类分箱**：使用 `FeatureEngineer.adaptive_binning()`（Mean Shift 密度聚类）进行自适应分箱。
#
# ### （三）变量热编码
# - 使用 `FeatureEngineer.preprocess_data()` 一次性生成三种编码策略：
#   - **全热编码 (one_hot)**：所有分类列 OneHot 编码
#   - **混合编码 (mixed)**：分类 OneHot + 数值 Min-Max 标准化
#   - **标准化 (standardized)**：分类保留 + 数值 Z-score 标准化
#
# ## 三、关联规则分析
#
# ### （一）Apriori 与 FP-Growth
# - 使用 `AssociationRuleMiner.mine_association_rules()` 挖掘频繁项集和关联规则。
# - 使用 `find_loss_related_rules()` 筛选流失相关规则。
# - 使用 `rule_quality_report()` 生成规则质量报告。
#
# ### （二）FP-Growth 参数优化：随机搜索
# - 使用 `AssociationRuleMiner.optimize_parameters()` 进行参数随机搜索优化。
# - 评估指标：支持度、置信度、提升度 (Lift)、Kulczynski 度量。
#
# ## 四、聚类分析
#
# ### （一）K-Means 聚类
# - 使用 `ClusterAnalyzer.kmeans_clustering()` 进行 K-Means 聚类。
# - 使用 `analyze_cluster_characteristics()` 分析聚类特征。
# - 使用 `stability_test()` 测试聚类稳定性。
#
# ### （二）K-Prototypes 聚类
# - 使用 `ClusterAnalyzer.kprototypes_clustering()` 处理混合数据类型。
#
# ## 五、流失预测建模（新增）
#
# - 使用 `ChurnPredictor` 进行三模型对比（LR / RF / XGBoost）。
# - GridSearchCV + StratifiedKFold 超参调优。
# - 自动选择最佳模型并持久化。
#
# ### SHAP 模型可解释性（新增）
# - 使用 `ModelExplainer.explain()` 进行 SHAP 特征重要性分析。
# - TreeExplainer（树模型）/ LinearExplainer（线性模型）自动选择。
#
# ## 六、总结与业务建议

# %% [markdown]
# # 一、数据预览与质量评估

# %%
# 基础库导入
 
import pandas as pd
import numpy as np
import os
import sys
import time
from pathlib import Path
from copy import deepcopy

 
# 可视化库导入
 
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display, HTML

 
# ============================================================
# src/ 模块导入 — 项目架构的核心计算模块
# ============================================================

# 确保项目根目录在 sys.path 上
# 策略：从当前工作目录向上查找包含 pyproject.toml 的目录
_candidate = Path(os.getcwd()).resolve()
PROJECT_ROOT = _candidate
while _candidate != _candidate.parent:
    if (_candidate / "pyproject.toml").exists():
        PROJECT_ROOT = _candidate
        break
    _candidate = _candidate.parent

# 切换到项目根目录（确保所有相对路径正确解析）
os.chdir(str(PROJECT_ROOT))

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.data_loader import DataLoader
from src.feature_engineering import FeatureEngineer
from src.association_rules import AssociationRuleMiner
from src.clustering import ClusterAnalyzer
from src.prediction import ChurnPredictor
from src.explainability import ModelExplainer
from src.visualization import DataVisualizer
from src.utils.helpers import detect_outliers_iqr, get_categorical_columns
from src.config.settings import config


# ============================================================
# 全局配置
# ============================================================

# seaborn 样式配置
sns.set_theme(style="whitegrid", palette="viridis")
sns.set_context("paper", font_scale=1.2)

# matplotlib 中文字体配置
try:
    plt.rcParams['font.sans-serif'] = ['WenQuanYi Micro Hei', 'SimHei', 'DejaVu Sans']
    plt.rcParams['axes.unicode_minus'] = False
    plt.rcParams['figure.dpi'] = 150
    plt.rcParams['savefig.dpi'] = 300
except:
    print("警告：中文字体配置失败，可能无法正确显示中文")

# 随机种子（确保可重复性）
RANDOM_STATE = config.data.random_seed
np.random.seed(RANDOM_STATE)

# 数据文件路径（使用 config 模块的默认路径）
DATA_FILE = config.data.raw_data_path

 
# ============================================================
# 工具函数（notebook 内联辅助）
# ============================================================
 
def q(df_slice, justify="center"):
    """
    智能显示控制 - 美化DataFrame输出
    
    参数:
        df_slice: 要显示的DataFrame
        justify: 对齐方式 ('left', 'center', 'right')
    """
    display(HTML(df_slice.to_html(justify=justify)))


def plot_histograms(df, cols, title="数值变量分布", figsize=(15, 10)):
    """
    绘制数值变量的直方图（notebook 内联可视化）
    """
    df[cols].hist(figsize=figsize, bins=30, xlabelsize=10, ylabelsize=10, edgecolor='black')
    plt.suptitle(title, fontsize=16, y=1.02)
    plt.tight_layout()
    plt.show()


def plot_boxplots(df, cols, title="数值变量箱线图", figsize=(15, 10)):
    """
    绘制数值变量的箱线图（用于异常值检测）
    """
    num_plots = len(cols)
    num_columns = 3
    num_rows = (num_plots + num_columns - 1) // num_columns
    
    fig, axes = plt.subplots(num_rows, num_columns, figsize=figsize)
    axes = axes.flatten() if isinstance(axes, np.ndarray) else [axes]
    
    for i, col in enumerate(cols):
        sns.boxplot(x=df[col], ax=axes[i], color='skyblue')
        axes[i].set_title(f'{col}', fontsize=12, fontweight='bold')
        axes[i].set_xlabel('Value', fontsize=10)
        axes[i].tick_params(axis='both', which='major', labelsize=8)
    
    for j in range(num_plots, num_rows * num_columns):
        axes[j].axis('off')
    
    plt.suptitle(title, fontsize=16, y=1.02)
    plt.tight_layout()
    plt.show()


def plot_countplots(df, cols, title="分类变量频次分布", figsize=(15, 10)):
    """
    绘制分类变量的计数图
    """
    num_plots = len(cols)
    num_columns = 3
    num_rows = (num_plots + num_columns - 1) // num_columns
    
    fig, axes = plt.subplots(num_rows, num_columns, figsize=figsize)
    axes = axes.flatten() if isinstance(axes, np.ndarray) else [axes]
    
    for i, col in enumerate(cols):
        sns.countplot(x=col, data=df, ax=axes[i], hue=col, palette='viridis', legend=False)
        axes[i].set_title(f'{col}', fontsize=12, fontweight='bold')
        axes[i].set_xlabel(col, fontsize=10)
        axes[i].set_ylabel('频次', fontsize=10)
        axes[i].tick_params(axis='both', which='major', labelsize=8)
    
    for j in range(num_plots, num_rows * num_columns):
        axes[j].axis('off')
    
    plt.suptitle(title, fontsize=16, y=1.02)
    plt.tight_layout()
    plt.show()


print("客户流失分析项目")
print(f"项目根目录: {PROJECT_ROOT}")
print(f"数据文件: {DATA_FILE}")
print(f"随机种子: {RANDOM_STATE}")
# Out:
# 客户流失分析项目
# 项目根目录: /home/wg/文档/Learning/Project/customer_churn_analysis
# 数据文件: data/customer_churn_data.xlsx
# 随机种子: 42

# %% [markdown]
# ## （一）数据预览

# %%
# Section 1: 数据预览与质量评估
 

 
# 1.1 数据加载 — 使用 src.data_loader.DataLoader
 
print("正在加载数据...")

# 使用 DataLoader 加载数据（自动处理 Excel/CSV，LRU 缓存 + 内存优化）
loader = DataLoader()
raw_df = loader.load_data()  # 默认使用 config.data.raw_data_path

print(f"✓ 客户流失数据加载完成: {raw_df.shape[0]} 行, {raw_df.shape[1]} 列")

# 使用 generate_data_report 生成结构化数据质量报告
report = loader.generate_data_report(raw_df)
print(f"✓ 数据质量报告已生成")

print(f"\n数据加载完成！")
# Out:
# INFO:src.data_loader:正在加载数据: data/customer_churn_data.xlsx
# INFO:src.data_loader:数据加载完成 - 形状: (901, 19), 耗时: 0.19s, 内存: 0.16MB
# INFO:src.data_loader:数据加载完成 - 内存使用: 381.99 MB
# 正在加载数据...
# ✓ 客户流失数据加载完成: 901 行, 19 列
# ✓ 数据质量报告已生成
#
# 数据加载完成！

# %%
 
# 1.2 数据预览
 
print("数据前5行预览:")
q(raw_df.head())

print("\n数据基础信息:")
raw_df.info()

print("\n数据统计摘要:")
q(raw_df.describe().round(2))

 
# 数据集说明
 
print("\n" + "=" * 80)
print("数据集说明")
print("=" * 80)
print(f"样本数量: {raw_df.shape[0]}")
print(f"特征数量: {raw_df.shape[1]}")
print(f"流失率: {raw_df['用户流失标签'].mean():.2%}")
# Out:
# 数据前5行预览:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: center;">
#       <th></th>
#       <th>顾客ID</th>
#       <th>用户流失标签</th>
#       <th>使用平台时间_月</th>
#       <th>常用登陆设备</th>
#       <th>城市等级</th>
#       <th>仓库到顾客地址</th>
#       <th>婚姻情况</th>
#       <th>年龄分组</th>
#       <th>性别</th>
#       <th>使用App时间_时</th>
#       <th>上月订单数量单</th>
#       <th>订单数量较去年增加_单</th>
#       <th>距上次下单天数_天</th>
#       <th>上月客户的首选订单类别</th>
#       <th>用户关注的主播数量</th>
#       <th>顾客对服务的满意度</th>
#       <th>上月投诉次数</th>
#       <th>上月使用的优惠劵数量_张</th>
#       <th>上月平均折扣金额</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>50001</td>
#       <td>1</td>
#       <td>4</td>
#       <td>Mobile Phone</td>
#       <td>3</td>
#       <td>6</td>
#       <td>Single</td>
#       <td>3</td>
#       <td>Female</td>
#       <td>3</td>
#       <td>1</td>
#       <td>11</td>
#       <td>5</td>
#       <td>Laptop &amp; Accessory</td>
#       <td>9</td>
# ...

# %%
# 1.3 数据质量评估
 
print("【缺失值检测】")
missing_values = raw_df.isnull().sum()
if missing_values.sum() == 0:
    print("✓ 数据中不存在缺失值")
else:
    print("发现缺失值:")
    q(missing_values[missing_values > 0].to_frame("缺失数量"))

print("\n【重复值检测】")
duplicates_count = raw_df.duplicated().sum()
if duplicates_count == 0:
    print("✓ 数据中不存在重复值")
else:
    print(f"发现 {duplicates_count} 行重复值，已删除")
    raw_df.drop_duplicates(inplace=True)

# 使用 src.utils.helpers.detect_outliers_iqr 进行 IQR 异常值检测
num_cols_all = raw_df.select_dtypes(include=['int64', 'float64']).columns.tolist()
if '顾客ID' in num_cols_all:
    num_cols_all.remove('顾客ID')

print(f"\n【数据类型检查】")
print(raw_df.dtypes)

print(f"\n【IQR 异常值检测（使用 src.utils.helpers）】")
outlier_summary_data = []
for col in num_cols_all:
    mask = detect_outliers_iqr(raw_df[col])
    count = mask.sum()
    if count > 0:
        Q1 = raw_df[col].quantile(0.25)
        Q3 = raw_df[col].quantile(0.75)
        IQR = Q3 - Q1
        outlier_summary_data.append({
            '列名': col,
            '异常值数量': count,
            '异常值比例': f"{count/len(raw_df)*100:.2f}%",
            '下限': round(Q1 - 1.5 * IQR, 2),
            '上限': round(Q3 + 1.5 * IQR, 2)
        })

if outlier_summary_data:
    outlier_summary = pd.DataFrame(outlier_summary_data)
    print(f"发现 {len(outlier_summary)} 个特征存在异常值：")
    q(outlier_summary)
else:
    print("✓ 未检测到 IQR 异常值")
# Out:
# 【缺失值检测】
# ✓ 数据中不存在缺失值
#
# 【重复值检测】
# ✓ 数据中不存在重复值
#
# 【数据类型检查】
# 顾客ID              int64
# 用户流失标签            int64
# 使用平台时间_月          int64
# 常用登陆设备              str
# 城市等级              int64
# 仓库到顾客地址           int64
# 婚姻情况                str
# 年龄分组              int64
# 性别                  str
# 使用App时间_时         int64
# 上月订单数量单           int64
# 订单数量较去年增加_单       int64
# 距上次下单天数_天         int64
# 上月客户的首选订单类别         str
# 用户关注的主播数量         int64
# 顾客对服务的满意度         int64
# 上月投诉次数            int64
# 上月使用的优惠劵数量_张      int64
# 上月平均折扣金额        float64
# dtype: object
#
# 【IQR 异常值检测（使用 src.utils.helpers）】
# 发现 8 个特征存在异常值：
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: center;">
#       <th></th>
#       <th>列名</th>
#       <th>异常值数量</th>
#       <th>异常值比例</th>
#       <th>下限</th>
#       <th>上限</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>用户流失标签</td>
#       <td>172</td>
#       <td>19.09%</td>
#       <td>0.00</td>
# ...

# %% [markdown]
# ##  （二）数据质量评估
# - **缺失值检测与处理**

# %% [markdown]
#  **重复值检测与处理**： 检测是否存在重复值行，如果存在，删除重复行。

# %% [markdown]
# - **异常值检测与处理**

# %% [markdown]
# - 数值数据

# %%
# 1.4 数据可视化 - 数值变量
 

# 获取数值型列（排除顾客ID）
num_cols = raw_df.select_dtypes(include=['int64', 'float64']).columns.tolist()
if '顾客ID' in num_cols:
    num_cols.remove('顾客ID')

print("【数值变量分布】")
plot_histograms(raw_df, num_cols, title="数值变量分布直方图")

print("\n【数值变量箱线图 - 异常值检测】")
plot_boxplots(raw_df, num_cols, title="数值变量箱线图（异常值检测）")
# Out:
# 【数值变量分布】
# 【数值变量箱线图 - 异常值检测】

# %% [markdown]
# - 分类数据

# %%
# 1.5 数据可视化 - 分类变量
 
# 创建用于可视化的副本（避免修改下游使用的 raw_df）
plot_df = raw_df.copy()

# 将数值型的分类变量转换为对象类型
categorical_numeric_cols = ['用户流失标签', '城市等级', '使用App时间_时', '上月投诉次数', '年龄分组', '顾客对服务的满意度']
for col in categorical_numeric_cols:
    if col in plot_df.columns:
        plot_df[col] = plot_df[col].astype(str)

# 使用 src.utils.helpers 辅助获取分类列
cat_cols = get_categorical_columns(plot_df)

print(f"【分类变量概览】")
print(f"分类变量数量: {len(cat_cols)}")
print(f"分类变量列表: {cat_cols}")

print("\n【分类变量分布】")
plot_countplots(plot_df, cat_cols, title="分类变量频次分布")
# Out:
# 【分类变量概览】
# 分类变量数量: 10
# 分类变量列表: ['用户流失标签', '常用登陆设备', '城市等级', '婚姻情况', '年龄分组', '性别', '使用App时间_时', '上月客户的首选订单类别', '顾客对服务的满意度', '上月投诉次数']
#
# 【分类变量分布】

# %% [markdown]
# # 二、数据处理

# %% [markdown]
# ## （一）数据筛选

# %%
# Section 2: 数据处理与特征工程
 

 
# 2.1 数据筛选
 
# 深复制原始数据，创建工作副本
df = deepcopy(raw_df)

# 删除顾客ID（分析不需要）
if '顾客ID' in df.columns:
    df.drop('顾客ID', axis=1, inplace=True)

# 识别分类列和数值列
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()
numeric_cols = df.select_dtypes(include=['number']).columns.tolist()

# 原始数值列（用于后续标准化参考）
raw_numeric_cols = [col for col in raw_df.select_dtypes(include=['number']).columns 
                    if col not in ['顾客ID', '用户流失标签']]

print(f"【数据预处理概览】")
print(f"总列数: {len(df.columns)}")
print(f"分类特征数量: {len(categorical_cols)}")
print(f"数值特征数量: {len(numeric_cols)}")
print(f"\n分类特征: {categorical_cols}")
print(f"\n数值特征: {numeric_cols}")

# 初始化 FeatureEngineer（将在后续单元格中复用）
fe = FeatureEngineer()
print(f"\n✓ FeatureEngineer 已初始化")
# Out:
# 【数据预处理概览】
# 总列数: 18
# 分类特征数量: 4
# 数值特征数量: 14
#
# 分类特征: ['常用登陆设备', '婚姻情况', '性别', '上月客户的首选订单类别']
#
# 数值特征: ['用户流失标签', '使用平台时间_月', '城市等级', '仓库到顾客地址', '年龄分组', '使用App时间_时', '上月订单数量单', '订单数量较去年增加_单', '距上次下单天数_天', '用户关注的主播数量', '顾客对服务的满意度', '上月投诉次数', '上月使用的优惠劵数量_张', '上月平均折扣金额']
#
# ✓ FeatureEngineer 已初始化
# /tmp/claude-1000/ipykernel_1146776/2734518890.py:15: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

# %% [markdown]
# ## （二）数值变量离散化

# %% [markdown]
# ### 1、自定义分箱

# %% [markdown]
# ### 2、聚类分箱：Mean Shift 密度聚类：网格搜索参数优化

# %% [markdown]
# 使用mean shift算法聚类分箱，使用网格搜索进行最佳宽带搜索

# %%
# 2.2 数值变量离散化 - Mean Shift 密度聚类
 
# 理论背景：
# - Mean Shift 是一种基于密度的非参数聚类算法，无需预先指定聚类数
# - 通过寻找概率密度函数的局部极大值来确定聚类中心
# - 此处直接调用 sklearn 的 MeanShift，展示底层 API 用法
 

from sklearn.cluster import MeanShift

def apply_mean_shift_binning(df, cols, verbose=True):
    """
    对数值列进行 MeanShift 聚类分箱
    
    参数:
        df: 数据框
        cols: 要分箱的数值列列表
        verbose: 是否打印详细信息
    
    返回:
        df: 分箱后的数据框
        results_df: 分箱结果摘要
    """
    binning_results = []
    start_time = time.time()
    
    for i, col in enumerate(cols):
        if col not in df.columns:
            continue
        
        if verbose:
            print(f"处理列 {i+1}/{len(cols)}: {col}")
        
        # 准备数据：reshape 为二维数组（MeanShift 要求）
        clean_vals = df[col].dropna().values.reshape(-1, 1)
        
        # MeanShift 密度聚类
        ms = MeanShift(bandwidth=None, bin_seeding=True, n_jobs=-1)
        clusters = ms.fit_predict(clean_vals)
        
        # 将聚类标签写回 Series
        # 注意：将 int 标签转为 str，使下游将其视为分类变量
        result = pd.Series(index=df[col].index, dtype='object')
        result[df[col].notna()] = clusters.astype(str)
        df[col] = result
        
        n_bins = df[col].nunique()
        binning_results.append({
            '列名': col,
            '分箱数': n_bins,
            '聚类中心数': len(np.unique(clusters))
        })
        
        if verbose:
            print(f"  → {n_bins} 个分箱 ({len(np.unique(clusters))} 个聚类中心)")
    
    elapsed = time.time() - start_time
    
    if verbose:
        print(f"\n{'='*60}")
        print(f"Mean Shift 分箱完成，耗时: {elapsed:.2f}秒")
        print(f"{'='*60}")
    
    return df, pd.DataFrame(binning_results)

# 获取需要分箱的数值列
num_cols_to_bin = [col for col in raw_numeric_cols if col in df.columns]

print("【Mean Shift 密度聚类分箱】")
print(f"将分箱 {len(num_cols_to_bin)} 个数值特征...")

df, best_params_df = apply_mean_shift_binning(df, num_cols_to_bin, verbose=True)

print(f"\n【分箱结果摘要】")
q(best_params_df)

print(f"\n分箱后数据框中所有列均变为 object 类型，适合后续全热编码处理。")
df.info()
# Out:
# 【Mean Shift 密度聚类分箱】
# 将分箱 13 个数值特征...
# 处理列 1/13: 使用平台时间_月
#   → 4 个分箱 (4 个聚类中心)
# 处理列 2/13: 城市等级
#   → 3 个分箱 (3 个聚类中心)
# 处理列 3/13: 仓库到顾客地址
#   → 3 个分箱 (3 个聚类中心)
# 处理列 4/13: 年龄分组
#   → 5 个分箱 (5 个聚类中心)
# 处理列 5/13: 使用App时间_时
#   → 4 个分箱 (4 个聚类中心)
# 处理列 6/13: 上月订单数量单
#   → 6 个分箱 (6 个聚类中心)
# 处理列 7/13: 订单数量较去年增加_单
#   → 3 个分箱 (3 个聚类中心)
# 处理列 8/13: 距上次下单天数_天
#   → 3 个分箱 (3 个聚类中心)
# 处理列 9/13: 用户关注的主播数量
#   → 6 个分箱 (6 个聚类中心)
# 处理列 10/13: 顾客对服务的满意度
#   → 4 个分箱 (4 个聚类中心)
# 处理列 11/13: 上月投诉次数
#   → 2 个分箱 (2 个聚类中心)
# 处理列 12/13: 上月使用的优惠劵数量_张
#   → 15 个分箱 (15 个聚类中心)
# 处理列 13/13: 上月平均折扣金额
#   → 3 个分箱 (3 个聚类中心)
#
# ...
# Mean Shift 分箱完成，耗时: 5.44秒
# ...
#
# 【分箱结果摘要】
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: center;">
#       <th></th>
#       <th>列名</th>
#       <th>分箱数</th>
#       <th>聚类中心数</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>使用平台时间_月</td>
#       <td>4</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...

# %% [markdown]
# ## （三）变量热编码

# %% [markdown]
# ### 1、对 df 进行全热编码

# %%
# 2.3 特征编码
 
# 注意：df 已通过 MeanShift 分箱变成全 object 类型
# - 对分箱后的 df 使用 pd.get_dummies 进行全热编码（用于关联规则挖掘）
# - 对原始数据使用 FeatureEngineer.preprocess_data() 生成混合编码和标准化（用于聚类）
 

# ---- 全热编码（分箱后的 df，用于关联规则） ----
df_encoded = pd.get_dummies(df, drop_first=True)
bool_columns = df_encoded.select_dtypes(include='bool').columns
df_encoded[bool_columns] = df_encoded[bool_columns].astype(int)

print(f"全热编码后维度: {df_encoded.shape[0]} 行 × {df_encoded.shape[1]} 列")
print(f"列名示例（前5列）: {list(df_encoded.columns[:5])}")

# ---- 原始数据编码（用于聚类分析） ----
# 使用原始 raw_df（保留数值列的原始 dtype），通过 FeatureEngineer 生成编码
# 注意：传入 raw_df（删除了顾客ID的原始副本）
raw_for_fe = deepcopy(raw_df)
if '顾客ID' in raw_for_fe.columns:
    raw_for_fe.drop('顾客ID', axis=1, inplace=True)

# 确保用户流失标签是数值型
if '用户流失标签' in raw_for_fe.columns:
    raw_for_fe['用户流失标签'] = pd.to_numeric(raw_for_fe['用户流失标签'], errors='coerce')

datasets = fe.preprocess_data(raw_for_fe)
mixed_encoded = datasets['mixed']          # 混合编码：分类 OneHot + 数值 MinMax
standard_encoded = datasets['standardized']  # 标准化：分类保留 + 数值 Z-score

print(f"\n混合编码后维度: {mixed_encoded.shape[0]} 行 × {mixed_encoded.shape[1]} 列")
print(f"标准化后维度: {standard_encoded.shape[0]} 行 × {standard_encoded.shape[1]} 列")
print(f"\n✓ 全热编码（用于关联规则）: {df_encoded.shape}")
print(f"✓ 混合编码（用于 K-Means）: {mixed_encoded.shape}")
print(f"✓ 标准化（用于 K-Prototypes）: {standard_encoded.shape}")
# Out:
# INFO:src.feature_engineering:开始数据预处理...
# INFO:src.feature_engineering:创建全热编码数据集...
# INFO:src.utils.performance:📊 性能分析 [_create_one_hot_encoded]:
# INFO:src.utils.performance:   - 耗时: 0.0169s
# INFO:src.utils.performance:   - 内存变化: +0.30 MB (当前占用: 483.58 MB)
# INFO:src.feature_engineering:创建混合编码数据集...
# INFO:src.utils.performance:📊 性能分析 [_create_mixed_encoded]:
# INFO:src.utils.performance:   - 耗时: 0.0089s
# INFO:src.utils.performance:   - 内存变化: +0.04 MB (当前占用: 483.62 MB)
# INFO:src.feature_engineering:创建标准化数据集...
# INFO:src.utils.performance:📊 性能分析 [_create_standardized]:
# INFO:src.utils.performance:   - 耗时: 0.0034s
# INFO:src.utils.performance:   - 内存变化: +0.00 MB (当前占用: 483.62 MB)
# INFO:src.feature_engineering:数据预处理完成
# INFO:src.utils.performance:📊 性能分析 [preprocess_data]:
# INFO:src.utils.performance:   - 耗时: 0.0334s
# INFO:src.utils.performance:   - 内存变化: +0.34 MB (当前占用: 483.62 MB)
# 全热编码后维度: 901 行 × 59 列
# ...

# %% [markdown]
# ### 2、对df1分类变量进行哑变量操作；连续数值进行最大最小归一化

# %%
# 混合编码已在 Cell 25 通过 FeatureEngineer.preprocess_data() 生成
# datasets['mixed'] = 分类变量 OneHot 编码 + 数值变量 Min-Max 标准化 (0~1)

mixed_df = mixed_encoded.copy()
print(f"混合编码后维度: {mixed_df.shape[0]} 行 × {mixed_df.shape[1]} 列")
print(f"✓ 分类变量已 OneHot 编码，数值变量已 Min-Max 标准化至 [0, 1]")
# Out:
# 混合编码后维度: 901 行 × 24 列
# ✓ 分类变量已 OneHot 编码，数值变量已 Min-Max 标准化至 [0, 1]

# %% [markdown]
# ### 3、对df3只进行数值标准化

# %%
# 标准化已在 Cell 25 通过 FeatureEngineer.preprocess_data() 生成
# datasets['standardized'] = 分类变量保留原值 + 数值变量 Z-score 标准化 (均值=0, 标准差=1)

standard_df = standard_encoded.copy()
print(f"标准化后维度: {standard_df.shape[0]} 行 × {standard_df.shape[1]} 列")
print(f"✓ 分类变量保留原值，数值变量已 Z-score 标准化")
# Out:
# 标准化后维度: 901 行 × 18 列
# ✓ 分类变量保留原值，数值变量已 Z-score 标准化

# %% [markdown]
# # 三、关联规则分析

# %% [markdown]
# ## （一）Apriori与FP-Growth

# %%
# 三、关联规则挖掘 — 使用 src.association_rules.AssociationRuleMiner
 
# 理论背景：
# - 关联规则挖掘用于发现数据项之间的关联关系
# - 支持度(Support): P(A∪B) - 项集在数据中出现的频率
# - 置信度(Confidence): P(B|A) - 条件概率
# - 提升度(Lift): P(B|A)/P(B) - >1正相关，<1负相关，=1独立
# - AssociationRuleMiner 封装了 Apriori/FP-Growth 算法 + 参数优化 + 流失规则筛选
 

 
# （一）Apriori 与 FP-Growth 算法
 

# 初始化 AssociationRuleMiner
miner = AssociationRuleMiner()

# 准备数据：将 one-hot 编码的 DataFrame 转换为布尔类型
# （AssociationRuleMiner 期望布尔格式，0/1 自动映射为 False/True）
bool_df = df_encoded.astype(bool)

target_col_name = '用户流失标签'
print(f"目标列 '{target_col_name}' 是否在数据中: {target_col_name in bool_df.columns}")

# ---- Apriori 算法 ----
print("\n【Apriori 算法】正在挖掘频繁项集...")
start_time = time.time()
apriori_result = miner.mine_association_rules(
    bool_df,
    algorithm='apriori',
    min_support=0.02,
    min_confidence=0.3
)
apriori_time = time.time() - start_time
print(f"Apriori 耗时: {apriori_time:.2f}秒")
print(f"  频繁项集: {apriori_result['itemset_count']} 个")
print(f"  关联规则: {apriori_result['rule_count']} 条")

# ---- FP-Growth 算法 ----
print("\n【FP-Growth 算法】正在挖掘频繁项集...")
start_time = time.time()
fpgrowth_result = miner.mine_association_rules(
    bool_df,
    algorithm='fp_growth',
    min_support=0.02,
    min_confidence=0.3
)
fpgrowth_time = time.time() - start_time
print(f"FP-Growth 耗时: {fpgrowth_time:.2f}秒")
print(f"  频繁项集: {fpgrowth_result['itemset_count']} 个")
print(f"  关联规则: {fpgrowth_result['rule_count']} 条")

# ---- 筛选流失相关规则 ----
# find_loss_related_rules() 自动筛选包含流失相关关键词且 Lift > 1 的规则
apriori_loss = miner.find_loss_related_rules(apriori_result['rules'])
fpgrowth_loss = miner.find_loss_related_rules(fpgrowth_result['rules'])

# ---- 算法性能对比 ----
print("\n" + "=" * 80)
print("【算法性能对比】")
print("=" * 80)
comparison = pd.DataFrame({
    '算法': ['Apriori', 'FP-Growth'],
    '耗时(秒)': [f"{apriori_time:.2f}", f"{fpgrowth_time:.2f}"],
    '频繁项集数': [apriori_result['itemset_count'], fpgrowth_result['itemset_count']],
    '总关联规则数': [apriori_result['rule_count'], fpgrowth_result['rule_count']],
    '流失相关规则数': [len(apriori_loss), len(fpgrowth_loss)]
})
q(comparison)

# ---- 展示 FP-Growth 流失相关规则 Top 10 ----
print(f"\n【FP-Growth - 与客户流失相关的关联规则】(共 {len(fpgrowth_loss)} 条)")
if fpgrowth_loss:
    display_rules = pd.DataFrame(fpgrowth_loss).head(10)
    show_cols = [c for c in ['antecedents', 'consequents', 'support', 'confidence', 'lift'] 
                 if c in display_rules.columns]
    q(display_rules[show_cols])

# ---- 规则质量报告 ----
quality = miner.rule_quality_report(fpgrowth_result['rules'])
print(f"\n【FP-Growth 规则质量概览】")
print(f"  规则总数: {quality['基本信息']['规则总数']}")
print(f"  平均支持度: {quality['基本信息']['平均支持度']:.4f}")
print(f"  平均置信度: {quality['基本信息']['平均置信度']:.4f}")
print(f"  平均提升度: {quality['基本信息']['平均提升度']:.4f}")
# Out:
# INFO:src.association_rules:开始使用 apriori 算法挖掘关联规则...
# INFO:src.association_rules:开始计算频繁项集...
# INFO:src.association_rules:关联规则挖掘完成 - 生成 3960 条规则
# 目标列 '用户流失标签' 是否在数据中: True
#
# 【Apriori 算法】正在挖掘频繁项集...
# INFO:src.utils.performance:📊 性能分析 [mine_association_rules]:
# INFO:src.utils.performance:   - 耗时: 0.0858s
# INFO:src.utils.performance:   - 内存变化: +20.83 MB (当前占用: 504.59 MB)
# INFO:src.association_rules:开始使用 fp_growth 算法挖掘关联规则...
# INFO:src.association_rules:开始计算频繁项集...
# Apriori 耗时: 0.09秒
#   频繁项集: 1946 个
#   关联规则: 3960 条
#
# 【FP-Growth 算法】正在挖掘频繁项集...
# INFO:src.association_rules:关联规则挖掘完成 - 生成 3960 条规则
# INFO:src.utils.performance:📊 性能分析 [mine_association_rules]:
# INFO:src.utils.performance:   - 耗时: 0.2413s
# INFO:src.utils.performance:   - 内存变化: -24.45 MB (当前占用: 480.14 MB)
# FP-Growth 耗时: 0.24秒
#   频繁项集: 1946 个
#   关联规则: 3960 条
# ...
# 【算法性能对比】
# ...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: center;">
#       <th></th>
#       <th>算法</th>
# ...

# %% [markdown]
# 整体结果分析
# 强关联因素：
# 从 lift 值来看，(上月投诉次数_1, 上月客户的首选订单类别_Household) 这条规则的 lift 值为 3.106476，是所有规则中最高的，说明上月有投诉且首选订单类别为家居用品的客户流失的可能性显著增加。
# (上月投诉次数_1) 这条规则的 lift 值为 1.848837，也表明上月有投诉的客户更容易流失。
# 业务建议：
# 对于家居用品订单类别，可优化服务质量，减少客户投诉，例如加强商品质量把控、提高物流速度等。
# 建立客户投诉反馈机制，及时处理客户投诉，提高客户满意度，从而降低客户流失率。

# %% [markdown]
# ## （二）FP-Growth参数优化：随机搜索

# %% [markdown]
# ### 1、结合多种关联规则质量指标的加权评分函数

# %%
# （二）FP-Growth 参数优化：随机搜索 — 使用 AssociationRuleMiner.optimize_parameters()
 
# optimize_parameters() 内部实现：
# 1. 在参数空间中随机采样
# 2. 对每组参数运行 FP-Growth
# 3. 使用综合评分函数（结合 lift 和规则数量）评估质量
# 4. 返回最优参数和对应规则
 

# 参数空间设计
param_space = {
    'min_support': list(np.geomspace(0.02, 0.2, num=8)),
    'min_confidence': list(np.linspace(0.3, 0.7, 5))
}

print("【FP-Growth 参数优化 — 随机搜索】")
print(f"参数空间: min_support ∈ [{min(param_space['min_support']):.4f}, {max(param_space['min_support']):.4f}]")
print(f"          min_confidence ∈ [{min(param_space['min_confidence']):.1f}, {max(param_space['min_confidence']):.1f}]")

start_time = time.time()

# 运行参数优化
opt_result = miner.optimize_parameters(
    bool_df,
    algorithm='fp_growth',
    param_space=param_space
)

elapsed = time.time() - start_time
print(f"\n参数优化耗时: {elapsed:.2f}秒")
print(f"最佳参数: {opt_result['optimal_params']}")
print(f"最佳评分: {opt_result['best_score']:.4f}")

# ---- 使用最优参数的结果 ----
final_result = opt_result['best_result']
final_loss_rules = miner.find_loss_related_rules(final_result['rules'])

print(f"\n最终流失相关关联规则: {len(final_loss_rules)} 条")
if final_loss_rules:
    final_rules_df = pd.DataFrame(final_loss_rules)
    show_cols = [c for c in ['antecedents', 'consequents', 'support', 'confidence', 'lift']
                 if c in final_rules_df.columns]
    q(final_rules_df[show_cols].head(10))

# ---- 最优参数下的规则质量报告 ----
final_quality = miner.rule_quality_report(final_result['rules'])
print(f"\n【最优参数规则质量】")
print(f"  规则总数: {final_quality['基本信息']['规则总数']}")
print(f"  平均支持度: {final_quality['基本信息']['平均支持度']:.4f}")
print(f"  平均提升度: {final_quality['基本信息']['平均提升度']:.4f}")
if '高质量规则' in final_quality:
    for k, v in final_quality['高质量规则'].items():
        print(f"  {k}: {v}")
# Out:
# INFO:src.association_rules:开始参数优化...
# INFO:src.association_rules:开始使用 fp_growth 算法挖掘关联规则...
# INFO:src.association_rules:开始计算频繁项集...
# INFO:src.association_rules:关联规则挖掘完成 - 生成 3 条规则
# INFO:src.utils.performance:📊 性能分析 [mine_association_rules]:
# INFO:src.utils.performance:   - 耗时: 0.0168s
# INFO:src.utils.performance:   - 内存变化: +0.01 MB (当前占用: 480.51 MB)
# INFO:src.association_rules:开始使用 fp_growth 算法挖掘关联规则...
# INFO:src.association_rules:开始计算频繁项集...
# INFO:src.association_rules:关联规则挖掘完成 - 生成 71 条规则
# INFO:src.utils.performance:📊 性能分析 [mine_association_rules]:
# INFO:src.utils.performance:   - 耗时: 0.0281s
# INFO:src.utils.performance:   - 内存变化: +0.00 MB (当前占用: 480.51 MB)
# INFO:src.association_rules:开始使用 fp_growth 算法挖掘关联规则...
# INFO:src.association_rules:开始计算频繁项集...
# INFO:src.association_rules:关联规则挖掘完成 - 生成 1 条规则
# INFO:src.utils.performance:📊 性能分析 [mine_association_rules]:
# INFO:src.utils.performance:   - 耗时: 0.0130s
# ...

# %% [markdown]
# 与用户流失相关的因素包括上月客户的首选订单类别为 “Household”、上月投诉次数为 1、婚姻情况为 “Single”、常用登陆设备为 “Phone”、顾客对服务的满意度为 3、使用 App 时间为 3 小时、距上次下单天数为 1 天、城市等级为 3 等。这些因素与用户流失标签之间存在一定的关联关系，可能是导致用户流失的潜在因素。

# %% [markdown]
# # 四、聚类分析

# %% [markdown]
# ## （一）K-Means

# %%
# 四、聚类分析 — 使用 src.clustering.ClusterAnalyzer
 
# 理论背景：
# - 聚类是无监督学习，用于将数据划分为若干组（簇）
# - K-Means: 基于距离的聚类，适合数值型数据
# - K-Prototypes: 支持混合数据类型（数值+分类）
# - ClusterAnalyzer 封装了 K-Means/K-Prototypes + 自动选K + 稳定性测试 + 特征分析
 

 
# （一）K-Means 聚类分析
 

# 初始化 ClusterAnalyzer
cluster_analyzer = ClusterAnalyzer()

# 准备数据：使用混合编码数据，去除目标列
target_col_kmeans = '用户流失标签'
X_kmeans = mixed_df.drop(columns=[target_col_kmeans]) if target_col_kmeans in mixed_df.columns else mixed_df.copy()

print(f"K-Means 输入维度: {X_kmeans.shape[0]} 行 × {X_kmeans.shape[1]} 列")

# K-Means 聚类（内部自动：StandardScaler + 肘部法/轮廓系数选择最佳K）
kmeans_result = cluster_analyzer.kmeans_clustering(X_kmeans)

print(f"\n【聚类结果】")
print(f"最佳聚类数 (K): {kmeans_result['n_clusters']}")
print(f"轮廓系数: {kmeans_result['metrics']['silhouette_score']:.4f}")
print(f"Calinski-Harabasz 指数: {kmeans_result['metrics']['calinski_harabasz']:.4f}")
print(f"Davies-Bouldin 指数: {kmeans_result['metrics']['davies_bouldin']:.4f}")

# ---- 聚类特征分析 ----
characteristics = cluster_analyzer.analyze_cluster_characteristics(X_kmeans, kmeans_result['labels'])
print(f"\n【各簇概况】")
for cluster_key, info in characteristics.items():
    print(f"  {cluster_key}: {info['size']} 个样本 ({info['percentage']:.1f}%)")

# ---- 聚类中心热力图（内联 matplotlib） ----
n_centers = kmeans_result['cluster_centers'].shape[1]
cluster_profile = pd.DataFrame(
    kmeans_result['cluster_centers'],
    columns=X_kmeans.columns[:n_centers]
)
plt.figure(figsize=(12, 8))
sns.heatmap(cluster_profile.T, annot=True, cmap='YlGnBu', fmt='.2f', 
            linewidths=.5, cbar_kws={'label': '标准化均值'})
plt.title('K-Means 聚类特征轮廓', fontsize=14, fontweight='bold')
plt.xlabel('簇', fontsize=12)
plt.ylabel('特征', fontsize=12)
plt.tight_layout()
plt.show()

# ---- t-SNE 降维可视化（内联，src ClusterAnalyzer 未提供） ----
from sklearn.manifold import TSNE
print("\n【t-SNE 降维可视化】")
tsne = TSNE(n_components=2, random_state=RANDOM_STATE, perplexity=30, max_iter=1000)
X_tsne = tsne.fit_transform(X_kmeans)
plt.figure(figsize=(10, 8))
scatter = plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=kmeans_result['labels'], cmap='viridis', alpha=0.6)
plt.colorbar(scatter, label='Cluster')
plt.title('K-Means 聚类结果 (t-SNE 降维)', fontsize=14, fontweight='bold')
plt.xlabel('t-SNE 1', fontsize=12)
plt.ylabel('t-SNE 2', fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ---- 稳定性测试 ----
print("\n【聚类稳定性测试】")
stability = cluster_analyzer.stability_test(
    X_kmeans, algorithm='kmeans', n_iterations=5
)
print(f"  稳定性等级: {stability['stability_level']}")
print(f"  平均 Rand Index: {stability['consistency_scores']['adjusted_rand_index']:.4f}")
print(f"  平均互信息: {stability['consistency_scores']['mutual_info']:.4f}")
# Out:
# INFO:src.clustering:开始K-Means聚类分析...
# K-Means 输入维度: 901 行 × 23 列
# INFO:src.clustering:WCSS 值列表: [18597.906393790607, 16996.301159804098, 15912.059601391476, 14914.67525326299, 14118.040725260513, 13624.293498561916, 13149.277072796995, 12783.870604037373, 12540.632166333275]
# INFO:src.clustering:轮廓系数列表: [0.09624642316470244, 0.1073367172434051, 0.12641847898064115, 0.15081464254475138, 0.14781825922288208, 0.13220220212866807, 0.13041233639826413, 0.12952718696251247, 0.12229337254580225]
# INFO:src.clustering:✅ 采用轮廓系数最高 K=5 (silhouette=0.1508)
# INFO:src.clustering:K-Means聚类完成 - 最佳K值: 5
# INFO:src.utils.performance:📊 性能分析 [kmeans_clustering]:
# INFO:src.utils.performance:   - 耗时: 1.3456s
# INFO:src.utils.performance:   - 内存变化: +1.29 MB (当前占用: 486.16 MB)
# 【聚类结果】
# 最佳聚类数 (K): 5
# 轮廓系数: 0.1508
# Calinski-Harabasz 指数: 87.2339
# Davies-Bouldin 指数: 1.9992
#
# 【各簇概况】
#   cluster_0: 49 个样本 (5.4%)
#   cluster_1: 445 个样本 (49.4%)
#   cluster_2: 258 个样本 (28.6%)
#   cluster_3: 78 个样本 (8.7%)
# ...

# %% [markdown]
# ## （二）K-Prototypes

# %% [markdown]
# ### 1、自动选择最佳聚类数（肘部法 + 轮廓系数）

# %%
# （二）K-Prototypes 聚类分析 — 使用 ClusterAnalyzer.kprototypes_clustering()
 
# K-Prototypes 专门用于处理混合数据类型（数值+分类）
# 数值型变量使用欧氏距离，分类变量使用简单匹配距离
 

# 准备数据：使用标准化数据（分类变量保留原值 + 数值变量标准化）
goal_clu = '用户流失标签'

# 识别分类列和数值列（使用 pd.api.types 避免 dtype 问题）
cat_cols_kproto = standard_df.select_dtypes(include=['object', 'category', 'string']).columns.tolist()
if goal_clu in cat_cols_kproto:
    cat_cols_kproto.remove(goal_clu)

num_cols_kproto = [c for c in standard_df.columns 
                   if c not in cat_cols_kproto + [goal_clu]
                   and pd.api.types.is_numeric_dtype(standard_df[c])]

print(f"【K-Prototypes 输入数据】")
print(f"  分类特征数量: {len(cat_cols_kproto)}")
print(f"  数值特征数量: {len(num_cols_kproto)}")

# 准备数据（去除目标列）
X_kproto = standard_df.drop(columns=[goal_clu]) if goal_clu in standard_df.columns else standard_df.copy()

# K-Prototypes 聚类（内部自动肘部法选择最佳K）
kproto_result = cluster_analyzer.kprototypes_clustering(
    X_kproto,
    categorical_cols=cat_cols_kproto,
    max_clusters=10
)

if 'error' not in kproto_result:
    print(f"\n【聚类结果】")
    print(f"最佳聚类数 (K): {kproto_result['n_clusters']}")
    
    metrics = kproto_result.get('metrics', {})
    if 'silhouette_score' in metrics:
        print(f"轮廓系数: {metrics['silhouette_score']:.4f}")
    if 'calinski_harabasz' in metrics:
        print(f"Calinski-Harabasz 指数: {metrics['calinski_harabasz']:.4f}")
    
    # ---- 数值特征聚类热力图（仅对数值列计算 mean） ----
    if num_cols_kproto:
        df_with_cluster = X_kproto.copy()
        df_with_cluster['Cluster'] = kproto_result['labels']
        profile = df_with_cluster.groupby('Cluster')[num_cols_kproto].mean()
        
        plt.figure(figsize=(12, 8))
        sns.heatmap(profile.T, annot=True, cmap='YlGnBu', fmt='.2f',
                    linewidths=.5, cbar_kws={'label': '平均值'})
        plt.title('K-Prototypes 聚类特征轮廓', fontsize=14, fontweight='bold')
        plt.xlabel('簇', fontsize=12)
        plt.ylabel('数值特征', fontsize=12)
        plt.tight_layout()
        plt.show()
    
    # ---- 各簇样本分布 ----
    cluster_sizes = pd.Series(kproto_result['labels']).value_counts().sort_index()
    print(f"\n【各簇样本分布】")
    for cid, size in cluster_sizes.items():
        print(f"  簇 {cid}: {size} 个样本 ({size/len(X_kproto)*100:.1f}%)")
    
    # ---- K-Prototypes 稳定性测试 ----
    print(f"\n【K-Prototypes 聚类稳定性测试】")
    kproto_stability = cluster_analyzer.stability_test(
        X_kproto, algorithm='kprototypes', n_iterations=5
    )
    print(f"  稳定性等级: {kproto_stability['stability_level']}")
    if 'adjusted_rand_index' in kproto_stability.get('consistency_scores', {}):
        print(f"  平均 Rand Index: {kproto_stability['consistency_scores']['adjusted_rand_index']:.4f}")
else:
    print(f"K-Prototypes 聚类失败: {kproto_result['error']}")
# Out:
# INFO:src.clustering:开始K-Prototypes聚类分析...
# INFO:src.clustering:寻找最佳 K，范围 2 ~ 10，分类列索引: [1, 4, 6, 11]
# 【K-Prototypes 输入数据】
#   分类特征数量: 4
#   数值特征数量: 13
# INFO:src.clustering:K-Prototypes 最佳 K = 5 (cost 列表长度=9)
# INFO:src.clustering:K-Prototypes聚类完成 - 最佳K值: 5
# INFO:src.utils.performance:📊 性能分析 [kprototypes_clustering]:
# INFO:src.utils.performance:   - 耗时: 10.6384s
# INFO:src.utils.performance:   - 内存变化: +0.34 MB (当前占用: 488.61 MB)
# 【聚类结果】
# 最佳聚类数 (K): 5
# 轮廓系数: 0.0817
# Calinski-Harabasz 指数: 86.8775
# INFO:src.clustering:开始kprototypes聚类稳定性测试...
# INFO:src.clustering:开始K-Prototypes聚类分析...
# INFO:src.clustering:寻找最佳 K，范围 2 ~ 5，分类列索引: [1, 4, 6, 11]
# 【各簇样本分布】
#   簇 0: 106 个样本 (11.8%)
#   簇 1: 298 个样本 (33.1%)
#   簇 2: 147 个样本 (16.3%)
#   簇 3: 209 个样本 (23.2%)
#   簇 4: 141 个样本 (15.6%)
#
# 【K-Prototypes 聚类稳定性测试】
# INFO:src.clustering:K-Prototypes 最佳 K = 3 (cost 列表长度=4)
# INFO:src.clustering:K-Prototypes聚类完成 - 最佳K值: 3
# INFO:src.utils.performance:📊 性能分析 [kprototypes_clustering]:
# ...

# %% [markdown]
# # 五、流失预测建模
#
# 使用三种分类器对比：逻辑回归 (Logistic Regression)、随机森林 (Random Forest)、XGBoost。
# 通过分层抽样拆分训练/测试集，使用 GridSearchCV + StratifiedKFold (k=5) 进行超参调优。
# 自动选择 ROC-AUC 最高的模型作为最终预测器。

# %%
# 五、流失预测建模 — 使用 src.prediction.ChurnPredictor
 

print("【流失预测建模】")
print("=" * 60)

# 初始化 ChurnPredictor
predictor = ChurnPredictor(random_state=RANDOM_STATE)

# Step 1: 数据准备（使用原始数据，predictor 内部自动处理编码和标准化）
#   - 自动识别数值/分类列
#   - 构建 ColumnTransformer (StandardScaler + OneHotEncoder)
#   - 分层抽样拆分训练/测试集
X_train, X_test, y_train, y_test = predictor.prepare_data(
    raw_df,                        # 原始数据（而非分箱后的 df）
    target_col='用户流失标签',
    test_size=0.2,
    id_cols=['顾客ID']
)

print(f"\n训练集: {X_train.shape[0]} 样本, {X_train.shape[1]} 特征")
print(f"测试集: {X_test.shape[0]} 样本, {X_test.shape[1]} 特征")
print(f"训练集流失率: {y_train.mean():.2%}")
print(f"测试集流失率: {y_test.mean():.2%}")

# Step 2: 模型训练（GridSearchCV + StratifiedKFold）
print(f"\n【模型训练 — GridSearchCV 超参调优 (k=5)】")
cv_results = predictor.train_models(X_train, y_train, cv_folds=5, n_jobs=-1)

# 展示交叉验证结果
cv_summary = []
for model_name, info in cv_results.items():
    cv_summary.append({
        '模型': model_name,
        '最佳CV分数': f"{info['best_cv_score']:.4f}",
        '平均CV分数': f"{info['cv_mean']:.4f}",
        'CV标准差': f"{info.get('cv_std', 0):.4f}",
        '训练时间(秒)': f"{info.get('train_time_seconds', 0):.1f}"
    })
print("\n【交叉验证结果】")
q(pd.DataFrame(cv_summary))
# Out:
# INFO:src.prediction:开始数据准备...
# INFO:src.prediction:丢弃 ID 列: ['顾客ID']
# INFO:src.prediction:特征数: 17, 样本数: 901
# INFO:src.prediction:正样本(流失)比例: 19.09%
# INFO:src.prediction:数值特征: 13, 分类特征: 4
# INFO:src.prediction:训练集: 720 样本, 测试集: 181 样本
# INFO:src.prediction:训练集正样本比例: 19.03%, 测试集正样本比例: 19.34%
# INFO:src.prediction:预处理后特征维度: 23
# INFO:src.prediction:数据准备完成
# INFO:src.utils.performance:📊 性能分析 [prepare_data]:
# INFO:src.utils.performance:   - 耗时: 0.0292s
# INFO:src.utils.performance:   - 内存变化: +0.00 MB (当前占用: 489.35 MB)
# INFO:src.prediction:开始模型训练 (CV=5, n_jobs=-1)...
# INFO:src.prediction:[LogisticRegression] 开始 GridSearchCV (参数组合数 ≈ 8)...
# INFO:src.prediction:[LogisticRegression] 完成 - best CV AUC=0.8660, 耗时=0.1s, best_params={'C': 1.0, 'max_iter': 2000, 'solver': 'liblinear'}
# INFO:src.prediction:[RandomForest] 开始 GridSearchCV (参数组合数 ≈ 72)...
# INFO:src.prediction:参数组合数从 72 缩减至 72
# 【流失预测建模】
# ...
#
# 训练集: 720 样本, 23 特征
# 测试集: 181 样本, 23 特征
# 训练集流失率: 19.03%
# 测试集流失率: 19.34%
#
# ...

# %% [markdown]
# ## 模型评估与 ROC 曲线

# %%
# Step 3: 测试集评估
 
metrics = predictor.evaluate_models(X_test, y_test)

# ---- 指标对比表 ----
metrics_data = []
for name, m in metrics.items():
    metrics_data.append({
        '模型': name,
        'Accuracy': m['accuracy'],
        'Precision': m['precision'],
        'Recall': m['recall'],
        'F1 Score': m['f1'],
        'ROC-AUC': m['roc_auc']
    })
metrics_table = pd.DataFrame(metrics_data).set_index('模型')
print("\n【测试集评估指标】")
q(metrics_table.round(4))

print(f"\n最佳模型: {predictor.best_model_name} (ROC-AUC: {metrics[predictor.best_model_name]['roc_auc']:.4f})")

# ---- 混淆矩阵 ----
print(f"\n【{predictor.best_model_name} 混淆矩阵】")
cm = metrics[predictor.best_model_name]['confusion_matrix']
print(f"  TN={cm[0][0]}, FP={cm[0][1]}, FN={cm[1][0]}, TP={cm[1][1]}")

# ---- ROC 曲线（内联 matplotlib） ----
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(10, 8))
colors = {'LogisticRegression': '#1f77b4', 'RandomForest': '#2ca02c', 'XGBoost': '#ff7f0e'}

for name in predictor.models:
    if hasattr(predictor, '_y_prob_test') and name in predictor._y_prob_test:
        fpr, tpr, _ = roc_curve(y_test, predictor._y_prob_test[name])
        roc_auc = metrics[name]['roc_auc']
        plt.plot(fpr, tpr, color=colors.get(name, '#333'), lw=2,
                 label=f'{name} (AUC={roc_auc:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=1, label='Random (AUC=0.50)')
plt.xlabel('False Positive Rate', fontsize=12)
plt.ylabel('True Positive Rate', fontsize=12)
plt.title('ROC Curves — 模型对比', fontsize=14, fontweight='bold')
plt.legend(loc='lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ---- Plotly 交互式 ROC（保存为 HTML） ----
try:
    roc_html_path = predictor.plot_roc_curves(X_test, y_test)
    print(f"\n交互式 ROC 曲线已保存: {roc_html_path}")
except Exception as e:
    print(f"\n交互式 ROC 生成失败（plotly 可能未安装）: {e}")

# ---- 保存模型和指标 ----
model_path = predictor.save_model()
metrics_path = predictor.save_metrics()
print(f"模型已保存: {model_path}")
print(f"指标已保存: {metrics_path}")
# Out:
# INFO:src.prediction:开始模型评估...
# INFO:src.prediction:[LogisticRegression] Acc=0.8287 Prec=0.5526 Rec=0.6000 F1=0.5753 AUC=0.8605
# INFO:src.prediction:[RandomForest] Acc=0.8343 Prec=0.7273 Rec=0.2286 F1=0.3478 AUC=0.8301
# INFO:src.prediction:[XGBoost] Acc=0.8729 Prec=0.7727 Rec=0.4857 F1=0.5965 AUC=0.8540
# INFO:src.prediction:🏆 最佳模型: LogisticRegression (ROC-AUC=0.8605)
# INFO:src.utils.performance:📊 性能分析 [evaluate_models]:
# INFO:src.utils.performance:   - 耗时: 0.0737s
# INFO:src.utils.performance:   - 内存变化: +0.13 MB (当前占用: 502.16 MB)
# 【测试集评估指标】
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: center;">
#       <th></th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>ROC-AUC</th>
#     </tr>
#     <tr>
#       <th>模型</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ## SHAP 模型可解释性分析
#
# 使用 SHAP (SHapley Additive exPlanations) 解释模型预测：
# - 线性模型 (LogisticRegression) → LinearExplainer
# - 树模型 (RandomForest, XGBoost) → TreeExplainer

# %%
# SHAP 模型可解释性 — 使用 src.explainability.ModelExplainer
 
print("【SHAP 特征重要性分析】")

if predictor.best_model is None:
    print("⚠️ 请先运行预测建模以获得最佳模型")
else:
    # 初始化 ModelExplainer
    explainer = ModelExplainer()
    
    # 自动推断模型类型
    if predictor.best_model_name == 'LogisticRegression':
        model_type = 'linear'
    else:
        model_type = 'tree'
    
    print(f"模型: {predictor.best_model_name}")
    print(f"解释器类型: {'LinearExplainer' if model_type == 'linear' else 'TreeExplainer'}")
    print(f"特征数量: {len(predictor.feature_names)}")
    
    # 运行 SHAP 分析（自动采样至 200 样本以加速计算）
    # 生成三张图表: summary, importance, dependence
    shap_outputs = explainer.explain(
        predictor.best_model,
        X_test,
        feature_names=predictor.feature_names,
        model_type=model_type,
        max_display=15
    )
    
    # ---- 展示 Top-15 SHAP 特征重要性 ----
    top_features = explainer.get_top_features(n=15)
    if top_features:
        print(f"\n【SHAP Top-15 特征重要性】")
        shap_data = []
        for f in top_features:
            idx = f['feature_index']
            name = predictor.feature_names[idx] if idx < len(predictor.feature_names) else f"Feature_{idx}"
            shap_data.append({
                '排名': f['rank'],
                '特征': name,
                'SHAP均值': f['mean_abs_shap']
            })
        q(pd.DataFrame(shap_data).set_index('排名'))
    
    print(f"\nSHAP 图表已保存至: {explainer.output_dir}")
    for key, path in shap_outputs.items():
        print(f"  {key}: {path}")
    
    # ---- 内联显示 SHAP 重要性图 ----
    from IPython.display import Image as IPImage
    if 'importance' in shap_outputs:
        print("\n【SHAP 特征重要性图】")
        display(IPImage(filename=shap_outputs['importance']))
# Out:
# INFO:src.explainability:开始 SHAP 分析 (type=linear, samples=181)...
# /home/wg/文档/Learning/Project/customer_churn_analysis/src/explainability.py:147: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(
# 【SHAP 特征重要性分析】
# 模型: LogisticRegression
# 解释器类型: LinearExplainer
# 特征数量: 23
# INFO:src.explainability:SHAP 摘要图: /home/wg/文档/Learning/Project/customer_churn_analysis/output/visualizations/shap_summary.png
# /home/wg/文档/Learning/Project/customer_churn_analysis/src/explainability.py:165: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(
# ...

# %%
# 使用 DataVisualizer 导出完整可视化报告
 

print("【生成可视化报告】")

visualizer = DataVisualizer(output_dir="output/visualizations")

# 1. 交互式仪表板（可能因数据类型问题失败，不影响整体流程）
try:
    dashboard_path = visualizer.create_interactive_dashboard(
        raw_df,
        kmeans_result,       # K-Means 聚类结果
        final_result          # FP-Growth 最优参数关联规则结果
    )
    print(f"✓ 交互式仪表板: {dashboard_path}")
except Exception as e:
    print(f"⚠ 交互式仪表板生成失败: {e}")

# 2. 数据分布图表
try:
    dist_plots = visualizer.create_data_distribution_plots(raw_df)
    print(f"✓ 数据分布图表: {len(dist_plots)} 个")
except Exception as e:
    print(f"⚠ 数据分布图表生成失败: {e}")
    dist_plots = []

# 3. 聚类分析图表
try:
    cluster_plots = visualizer.create_cluster_profile_plots(raw_df, kmeans_result)
    print(f"✓ 聚类分析图表: {len(cluster_plots)} 个")
except Exception as e:
    print(f"⚠ 聚类分析图表生成失败: {e}")
    cluster_plots = []

# 4. 关联规则图表
try:
    rule_plots = visualizer.create_association_rules_plots(final_result['rules'])
    print(f"✓ 关联规则图表: {len(rule_plots)} 个")
except Exception as e:
    print(f"⚠ 关联规则图表生成失败: {e}")
    rule_plots = []

# 5. 综合 HTML 报告
try:
    all_plots = dist_plots + cluster_plots + rule_plots
    if all_plots:
        html_report = visualizer.export_all_plots_to_html(all_plots)
        print(f"✓ 综合 HTML 报告: {html_report}")
except Exception as e:
    print(f"⚠ HTML 报告生成失败: {e}")

print(f"\n✓ 可视化导出完成 — 结果保存在 output/visualizations/")
# Out:
# INFO:src.visualization:创建交互式仪表板...
# INFO:src.visualization:交互式仪表板已保存: output/visualizations/interactive_dashboard.html
# INFO:src.utils.performance:📊 性能分析 [create_interactive_dashboard]:
# INFO:src.utils.performance:   - 耗时: 0.0403s
# INFO:src.utils.performance:   - 内存变化: +0.50 MB (当前占用: 541.32 MB)
# INFO:src.visualization:创建数据分布可视化...
# 【生成可视化报告】
# ✓ 交互式仪表板: output/visualizations/interactive_dashboard.html
# INFO:src.visualization:生成 7 个数据分布图表
# INFO:src.utils.performance:📊 性能分析 [create_data_distribution_plots]:
# INFO:src.utils.performance:   - 耗时: 5.3623s
# INFO:src.utils.performance:   - 内存变化: +32.12 MB (当前占用: 573.44 MB)
# INFO:src.visualization:创建聚类特征分析图表...
# ✓ 数据分布图表: 7 个
# /home/wg/文档/Learning/Project/customer_churn_analysis/src/visualization.py:301: Pandas4Warning: Starting with pandas version 4.0 all arguments of sum will be keyword-only.
#   cross_tab.div(cross_tab.sum(1), axis=0).plot(kind='bar', stacked=True, ax=plt.gca())
# ...

# %% [markdown]
# # 总结
#
# ## 1. 核心挖掘结论
#
# 本分析通过对 901 位客户的 19 项特征进行挖掘，得出以下核心结论：
#
# *流失现状*：整体流失率为 19.09%，处于需要预警的水平。
#
# *关键诱因*：通过 FP-Growth 随机搜索优化，发现"投诉记录"与"满意度低"是导致流失的最强关联因子。
#
# *人群画像*：通过 K-Means 和 K-Prototypes 聚类（均识别 5 个客户群体），轮廓系数分别为 0.15 和 0.08，表明聚类结构较弱，客户群体间边界模糊，需结合业务经验谨慎解读。
#
# *模型性能*：通过 LR/RF/XGBoost 三模型对比，LogisticRegression 以 ROC-AUC 0.86 表现最优，适合实际流失预警部署。
#
# *可解释性*：SHAP 分析揭示了驱动个体预测的关键特征，为业务决策提供透明依据。
#
# ## 2. 深度洞察与发现
#
# *(一)* 流失风险的"关联信号"
#
# 投诉的破坏力：在频繁项集挖掘中发现，一旦出现"上月投诉次数 > 0"，其流失的提升度（Lift）显著增加。
#
# 满意度阈值：满意度评分偏低的客户，即使曾是高活跃用户，流失概率也远高于均值。
#
# *(二)* 客户分群特征 (基于聚类结果)
#
# K-Means 聚类将客户分为 5 个群体：
# - 簇 0: 49 人 (5.4%) — 极小群体
# - 簇 1: 445 人 (49.4%) — 主流群体，占比近半
# - 簇 2: 258 人 (28.6%) — 第二大类
# - 簇 3: 78 人 (8.7%)
# - 簇 4: 71 人 (7.9%)
#
# K-Prototypes 同样识别 5 个群体，与 K-Means 结果相互印证（但需注意聚类稳定性 Rand Index ≈ 0，不同运行间结果变化较大，聚类划分缺乏稳健性）。建议更多依赖关联规则和预测模型进行决策。
#
# *(三)* 模型洞察
#
# LogisticRegression 在 ROC-AUC (0.86) 和 Recall (0.60) 上表现最佳，适合"宁可多预警，不漏过一个"的召回策略。Random Forest 在 Precision (0.73) 上最高，适合挽留预算有限的精准干预场景。XGBoost 在 Accuracy (0.87) 和整体平衡性上表现最好。
#
# ## 3. 商业行动建议
#
# *1*. 建立基于投诉的"快速响应机制"
# 策略：鉴于投诉与流失的强关联，建议建立"投诉即补救"流程。
# 行动：客户投诉后 24 小时内，客服需介入并提供定向优惠券，以对冲不满情绪。
#
# *2*. 精细化促销策略
# 策略：针对价格敏感型群体，减少普惠式折扣。
# 行动：利用关联规则中发现的品类偏好，进行精准交叉销售推送，提高其更换平台的成本。
#
# *3*. 动态预警系统
# 策略：利用预测模型（LogisticRegression, AUC 0.86）进行实时流失风险评分。
# 行动：对高风险客户自动触发挽回短信或定向优惠，同时对模型定期重训练以保持预测精度。
#
# ---
#
# *本 notebook 使用项目 src/ 模块进行核心计算。*
# *运行方式: `PYTHONPATH=. jupyter notebook` 或 `PYTHONPATH=. jupyter nbconvert --to notebook --execute notebooks/customer_churn_analysis.ipynb`*
